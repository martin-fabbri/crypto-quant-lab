# %%
import pandas as pd

Y_df = pd.read_parquet('https://datasets-nixtla.s3.amazonaws.com/m4-hourly.parquet')

Y_df.head()
# Out:
#   unique_id  ds      y
# 0        H1   1  605.0
# 1        H1   2  586.0
# 2        H1   3  586.0
# 3        H1   4  559.0
# 4        H1   5  511.0

# %%
uids = Y_df['unique_id'].unique()[:10] # Select 10 ids to make the example faster
Y_df = Y_df.query('unique_id in @uids').reset_index(drop=True)

# %%
from statsforecast import StatsForecast

StatsForecast.plot(Y_df, engine='matplotlib')
# Out:
# /Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/statsforecast/core.py:26: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
from ray import tune

from neuralforecast import NeuralForecast
from neuralforecast.auto import AutoNHITS, AutoLSTM
from neuralforecast.losses.pytorch import MQLoss

# %%
config_nhits = {
    "input_size": tune.choice([48, 48*2, 48*3]),              # Length of input window
    "start_padding_enabled": True,
    "n_blocks": 5*[1],                                              # Length of input window
    "mlp_units": 5 * [[64, 64]],                                  # Length of input window
    "n_pool_kernel_size": tune.choice([5*[1], 5*[2], 5*[4],         
                                      [8, 4, 2, 1, 1]]),            # MaxPooling Kernel size
    "n_freq_downsample": tune.choice([[8, 4, 2, 1, 1],
                                      [1, 1, 1, 1, 1]]),            # Interpolation expressivity ratios
    "learning_rate": tune.loguniform(1e-4, 1e-2),                   # Initial Learning rate
    "scaler_type": tune.choice([None]),                             # Scaler type
    "max_steps": tune.choice([1000]),                               # Max number of training iterations
    "batch_size": tune.choice([1, 4, 10]),                          # Number of series in batch
    "windows_batch_size": tune.choice([128, 256, 512]),             # Number of windows in batch
    "random_seed": tune.randint(1, 20),                             # Random seed
}

config_lstm = {
    "input_size": tune.choice([48, 48*2, 48*3]),              # Length of input window
    "encoder_hidden_size": tune.choice([64, 128]),            # Hidden size of LSTM cells
    "encoder_n_layers": tune.choice([2,4]),                   # Number of layers in LSTM
    "learning_rate": tune.loguniform(1e-4, 1e-2),             # Initial Learning rate
    "scaler_type": tune.choice(['robust']),                   # Scaler type
    "max_steps": tune.choice([500, 1000]),                    # Max number of training iterations
    "batch_size": tune.choice([1, 4]),                        # Number of series in batch
    "random_seed": tune.randint(1, 20),                       # Random seed
}

# %%
nf = NeuralForecast(
    models=[
        AutoNHITS(h=48, config=config_nhits, loss=MQLoss(), num_samples=5),
        AutoLSTM(h=48, config=config_lstm, loss=MQLoss(), num_samples=2),
    ],
    freq='H'
)

# %%
nf.fit(df=Y_df)
# Out:
# 2024-04-13 11:20:59,019	ERROR tune_controller.py:1332 -- Trial task failed for trial _train_tune_33873_00000
# Traceback (most recent call last):
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/ray/_private/worker.py", line 2667, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/ray/_private/worker.py", line 864, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(NotImplementedError): ray::ImplicitFunc.train() (pid=67953, ip=127.0.0.1, actor_id=234546ae7e9a0835ed8e2d0801000000, repr=_train_tune)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/ray/tune/trainable/trainable.py", line 334, in train
#     raise skipped from exception_cause(skipped)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/ray/air/_internal/util.py", line 88, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 53, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 261, in _trainable_func
#     output = fn()
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/ray/tune/trainable/util.py", line 130, in inner
#     return trainable(config, **fn_kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/neuralforecast/common/_base_auto.py", line 207, in _train_tune
#     _ = self._fit_model(
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/neuralforecast/common/_base_auto.py", line 336, in _fit_model
#     model.fit(dataset, val_size=val_size, test_size=test_size)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/neuralforecast/common/_base_windows.py", line 734, in fit
#     trainer.fit(self, datamodule=datamodule)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/trainer/trainer.py", line 544, in fit
#     call._call_and_handle_interrupt(
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/trainer/call.py", line 44, in _call_and_handle_interrupt
#     return trainer_fn(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/trainer/trainer.py", line 580, in _fit_impl
#     self._run(model, ckpt_path=ckpt_path)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/trainer/trainer.py", line 987, in _run
#     results = self._run_stage()
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/trainer/trainer.py", line 1031, in _run_stage
#     self._run_sanity_check()
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/trainer/trainer.py", line 1060, in _run_sanity_check
#     val_loop.run()
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/loops/utilities.py", line 182, in _decorator
#     return loop_run(self, *args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/loops/evaluation_loop.py", line 135, in run
#     self._evaluation_step(batch, batch_idx, dataloader_idx, dataloader_iter)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/loops/evaluation_loop.py", line 396, in _evaluation_step
#     output = call._call_strategy_hook(trainer, hook_name, *step_args)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/trainer/call.py", line 309, in _call_strategy_hook
#     output = fn(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/strategies/strategy.py", line 412, in validation_step
#     return self.lightning_module.validation_step(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/neuralforecast/common/_base_windows.py", line 574, in validation_step
#     output_batch = self(windows_batch)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1511, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1520, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/neuralforecast/models/nhits.py", line 392, in forward
#     backcast, block_forecast = block(
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1511, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1520, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/neuralforecast/models/nhits.py", line 179, in forward
#     backcast, forecast = self.basis(theta)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1511, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1520, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/neuralforecast/models/nhits.py", line 43, in forward
#     forecast = F.interpolate(
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/torch/nn/functional.py", line 4024, in interpolate
#     return torch._C._nn.upsample_linear1d(input, output_size, align_corners, scale_factors)
# NotImplementedError: The operator 'aten::upsample_linear1d.out' is not currently implemented for the MPS device. If you want this op to be added in priority during the prototype phase of this feature, please comment on https://github.com/pytorch/pytorch/issues/77764. As a temporary fix, you can set the environment variable `PYTORCH_ENABLE_MPS_FALLBACK=1` to use the CPU as a fallback for this op. WARNING: this will be slower than running natively on MPS.
# 2024-04-13 11:21:03,634	ERROR tune_controller.py:1332 -- Trial task failed for trial _train_tune_33873_00001
# Traceback (most recent call last):
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/ray/_private/worker.py", line 2667, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/ray/_private/worker.py", line 864, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(NotImplementedError): ray::ImplicitFunc.train() (pid=67959, ip=127.0.0.1, actor_id=65b1184bcbfc4f1e47f1da4401000000, repr=_train_tune)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/ray/tune/trainable/trainable.py", line 334, in train
#     raise skipped from exception_cause(skipped)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/ray/air/_internal/util.py", line 88, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 53, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 261, in _trainable_func
#     output = fn()
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/ray/tune/trainable/util.py", line 130, in inner
#     return trainable(config, **fn_kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/neuralforecast/common/_base_auto.py", line 207, in _train_tune
#     _ = self._fit_model(
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/neuralforecast/common/_base_auto.py", line 336, in _fit_model
#     model.fit(dataset, val_size=val_size, test_size=test_size)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/neuralforecast/common/_base_windows.py", line 734, in fit
#     trainer.fit(self, datamodule=datamodule)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/trainer/trainer.py", line 544, in fit
#     call._call_and_handle_interrupt(
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/trainer/call.py", line 44, in _call_and_handle_interrupt
#     return trainer_fn(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/trainer/trainer.py", line 580, in _fit_impl
#     self._run(model, ckpt_path=ckpt_path)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/trainer/trainer.py", line 987, in _run
#     results = self._run_stage()
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/trainer/trainer.py", line 1031, in _run_stage
#     self._run_sanity_check()
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/trainer/trainer.py", line 1060, in _run_sanity_check
#     val_loop.run()
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/loops/utilities.py", line 182, in _decorator
#     return loop_run(self, *args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/loops/evaluation_loop.py", line 135, in run
#     self._evaluation_step(batch, batch_idx, dataloader_idx, dataloader_iter)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/loops/evaluation_loop.py", line 396, in _evaluation_step
#     output = call._call_strategy_hook(trainer, hook_name, *step_args)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/trainer/call.py", line 309, in _call_strategy_hook
#     output = fn(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/strategies/strategy.py", line 412, in validation_step
#     return self.lightning_module.validation_step(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/neuralforecast/common/_base_windows.py", line 574, in validation_step
#     output_batch = self(windows_batch)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1511, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1520, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/neuralforecast/models/nhits.py", line 392, in forward
#     backcast, block_forecast = block(
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1511, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1520, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/neuralforecast/models/nhits.py", line 179, in forward
#     backcast, forecast = self.basis(theta)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1511, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1520, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/neuralforecast/models/nhits.py", line 43, in forward
#     forecast = F.interpolate(
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/torch/nn/functional.py", line 4024, in interpolate
#     return torch._C._nn.upsample_linear1d(input, output_size, align_corners, scale_factors)
# NotImplementedError: The operator 'aten::upsample_linear1d.out' is not currently implemented for the MPS device. If you want this op to be added in priority during the prototype phase of this feature, please comment on https://github.com/pytorch/pytorch/issues/77764. As a temporary fix, you can set the environment variable `PYTORCH_ENABLE_MPS_FALLBACK=1` to use the CPU as a fallback for this op. WARNING: this will be slower than running natively on MPS.
# 2024-04-13 11:21:08,626	ERROR tune_controller.py:1332 -- Trial task failed for trial _train_tune_33873_00002
# Traceback (most recent call last):
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/ray/_private/worker.py", line 2667, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/ray/_private/worker.py", line 864, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(NotImplementedError): ray::ImplicitFunc.train() (pid=67967, ip=127.0.0.1, actor_id=acc27bbe708532ac9b41cd1a01000000, repr=_train_tune)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/ray/tune/trainable/trainable.py", line 334, in train
#     raise skipped from exception_cause(skipped)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/ray/air/_internal/util.py", line 88, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 53, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 261, in _trainable_func
#     output = fn()
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/ray/tune/trainable/util.py", line 130, in inner
#     return trainable(config, **fn_kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/neuralforecast/common/_base_auto.py", line 207, in _train_tune
#     _ = self._fit_model(
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/neuralforecast/common/_base_auto.py", line 336, in _fit_model
#     model.fit(dataset, val_size=val_size, test_size=test_size)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/neuralforecast/common/_base_windows.py", line 734, in fit
#     trainer.fit(self, datamodule=datamodule)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/trainer/trainer.py", line 544, in fit
#     call._call_and_handle_interrupt(
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/trainer/call.py", line 44, in _call_and_handle_interrupt
#     return trainer_fn(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/trainer/trainer.py", line 580, in _fit_impl
#     self._run(model, ckpt_path=ckpt_path)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/trainer/trainer.py", line 987, in _run
#     results = self._run_stage()
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/trainer/trainer.py", line 1031, in _run_stage
#     self._run_sanity_check()
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/trainer/trainer.py", line 1060, in _run_sanity_check
#     val_loop.run()
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/loops/utilities.py", line 182, in _decorator
#     return loop_run(self, *args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/loops/evaluation_loop.py", line 135, in run
#     self._evaluation_step(batch, batch_idx, dataloader_idx, dataloader_iter)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/loops/evaluation_loop.py", line 396, in _evaluation_step
#     output = call._call_strategy_hook(trainer, hook_name, *step_args)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/trainer/call.py", line 309, in _call_strategy_hook
#     output = fn(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/strategies/strategy.py", line 412, in validation_step
#     return self.lightning_module.validation_step(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/neuralforecast/common/_base_windows.py", line 574, in validation_step
#     output_batch = self(windows_batch)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1511, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1520, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/neuralforecast/models/nhits.py", line 392, in forward
#     backcast, block_forecast = block(
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1511, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1520, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/neuralforecast/models/nhits.py", line 179, in forward
#     backcast, forecast = self.basis(theta)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1511, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1520, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/neuralforecast/models/nhits.py", line 43, in forward
#     forecast = F.interpolate(
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/torch/nn/functional.py", line 4024, in interpolate
#     return torch._C._nn.upsample_linear1d(input, output_size, align_corners, scale_factors)
# NotImplementedError: The operator 'aten::upsample_linear1d.out' is not currently implemented for the MPS device. If you want this op to be added in priority during the prototype phase of this feature, please comment on https://github.com/pytorch/pytorch/issues/77764. As a temporary fix, you can set the environment variable `PYTORCH_ENABLE_MPS_FALLBACK=1` to use the CPU as a fallback for this op. WARNING: this will be slower than running natively on MPS.
# 2024-04-13 11:21:13,545	ERROR tune_controller.py:1332 -- Trial task failed for trial _train_tune_33873_00003
# Traceback (most recent call last):
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/ray/_private/worker.py", line 2667, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/ray/_private/worker.py", line 864, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(NotImplementedError): ray::ImplicitFunc.train() (pid=67981, ip=127.0.0.1, actor_id=7b379297faa1df9162c7c3dd01000000, repr=_train_tune)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/ray/tune/trainable/trainable.py", line 334, in train
#     raise skipped from exception_cause(skipped)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/ray/air/_internal/util.py", line 88, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 53, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 261, in _trainable_func
#     output = fn()
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/ray/tune/trainable/util.py", line 130, in inner
#     return trainable(config, **fn_kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/neuralforecast/common/_base_auto.py", line 207, in _train_tune
#     _ = self._fit_model(
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/neuralforecast/common/_base_auto.py", line 336, in _fit_model
#     model.fit(dataset, val_size=val_size, test_size=test_size)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/neuralforecast/common/_base_windows.py", line 734, in fit
#     trainer.fit(self, datamodule=datamodule)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/trainer/trainer.py", line 544, in fit
#     call._call_and_handle_interrupt(
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/trainer/call.py", line 44, in _call_and_handle_interrupt
#     return trainer_fn(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/trainer/trainer.py", line 580, in _fit_impl
#     self._run(model, ckpt_path=ckpt_path)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/trainer/trainer.py", line 987, in _run
#     results = self._run_stage()
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/trainer/trainer.py", line 1031, in _run_stage
#     self._run_sanity_check()
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/trainer/trainer.py", line 1060, in _run_sanity_check
#     val_loop.run()
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/loops/utilities.py", line 182, in _decorator
#     return loop_run(self, *args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/loops/evaluation_loop.py", line 135, in run
#     self._evaluation_step(batch, batch_idx, dataloader_idx, dataloader_iter)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/loops/evaluation_loop.py", line 396, in _evaluation_step
#     output = call._call_strategy_hook(trainer, hook_name, *step_args)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/trainer/call.py", line 309, in _call_strategy_hook
#     output = fn(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/strategies/strategy.py", line 412, in validation_step
#     return self.lightning_module.validation_step(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/neuralforecast/common/_base_windows.py", line 574, in validation_step
#     output_batch = self(windows_batch)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1511, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1520, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/neuralforecast/models/nhits.py", line 392, in forward
#     backcast, block_forecast = block(
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1511, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1520, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/neuralforecast/models/nhits.py", line 179, in forward
#     backcast, forecast = self.basis(theta)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1511, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1520, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/neuralforecast/models/nhits.py", line 43, in forward
#     forecast = F.interpolate(
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/torch/nn/functional.py", line 4024, in interpolate
#     return torch._C._nn.upsample_linear1d(input, output_size, align_corners, scale_factors)
# NotImplementedError: The operator 'aten::upsample_linear1d.out' is not currently implemented for the MPS device. If you want this op to be added in priority during the prototype phase of this feature, please comment on https://github.com/pytorch/pytorch/issues/77764. As a temporary fix, you can set the environment variable `PYTORCH_ENABLE_MPS_FALLBACK=1` to use the CPU as a fallback for this op. WARNING: this will be slower than running natively on MPS.
# 2024-04-13 11:21:18,577	ERROR tune_controller.py:1332 -- Trial task failed for trial _train_tune_33873_00004
# Traceback (most recent call last):
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/ray/_private/worker.py", line 2667, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/ray/_private/worker.py", line 864, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(NotImplementedError): ray::ImplicitFunc.train() (pid=67987, ip=127.0.0.1, actor_id=b0b2847ffa09fdbdfbf8fb2b01000000, repr=_train_tune)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/ray/tune/trainable/trainable.py", line 334, in train
#     raise skipped from exception_cause(skipped)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/ray/air/_internal/util.py", line 88, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 53, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 261, in _trainable_func
#     output = fn()
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/ray/tune/trainable/util.py", line 130, in inner
#     return trainable(config, **fn_kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/neuralforecast/common/_base_auto.py", line 207, in _train_tune
#     _ = self._fit_model(
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/neuralforecast/common/_base_auto.py", line 336, in _fit_model
#     model.fit(dataset, val_size=val_size, test_size=test_size)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/neuralforecast/common/_base_windows.py", line 734, in fit
#     trainer.fit(self, datamodule=datamodule)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/trainer/trainer.py", line 544, in fit
#     call._call_and_handle_interrupt(
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/trainer/call.py", line 44, in _call_and_handle_interrupt
#     return trainer_fn(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/trainer/trainer.py", line 580, in _fit_impl
#     self._run(model, ckpt_path=ckpt_path)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/trainer/trainer.py", line 987, in _run
#     results = self._run_stage()
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/trainer/trainer.py", line 1031, in _run_stage
#     self._run_sanity_check()
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/trainer/trainer.py", line 1060, in _run_sanity_check
#     val_loop.run()
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/loops/utilities.py", line 182, in _decorator
#     return loop_run(self, *args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/loops/evaluation_loop.py", line 135, in run
#     self._evaluation_step(batch, batch_idx, dataloader_idx, dataloader_iter)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/loops/evaluation_loop.py", line 396, in _evaluation_step
#     output = call._call_strategy_hook(trainer, hook_name, *step_args)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/trainer/call.py", line 309, in _call_strategy_hook
#     output = fn(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/pytorch_lightning/strategies/strategy.py", line 412, in validation_step
#     return self.lightning_module.validation_step(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/neuralforecast/common/_base_windows.py", line 574, in validation_step
#     output_batch = self(windows_batch)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1511, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1520, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/neuralforecast/models/nhits.py", line 392, in forward
#     backcast, block_forecast = block(
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1511, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1520, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/neuralforecast/models/nhits.py", line 179, in forward
#     backcast, forecast = self.basis(theta)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1511, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1520, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/neuralforecast/models/nhits.py", line 43, in forward
#     forecast = F.interpolate(
#   File "/Users/martinfabbri/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/torch/nn/functional.py", line 4024, in interpolate
#     return torch._C._nn.upsample_linear1d(input, output_size, align_corners, scale_factors)
# NotImplementedError: The operator 'aten::upsample_linear1d.out' is not currently implemented for the MPS device. If you want this op to be added in priority during the prototype phase of this feature, please comment on https://github.com/pytorch/pytorch/issues/77764. As a temporary fix, you can set the environment variable `PYTORCH_ENABLE_MPS_FALLBACK=1` to use the CPU as a fallback for this op. WARNING: this will be slower than running natively on MPS.
# 2024-04-13 11:21:18,582	WARNING experiment_state.py:205 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this error by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0).
# 2024-04-13 11:21:18,586	INFO tune.py:1016 -- Wrote the latest version of all result files and experiment state to '/Users/martinfabbri/ray_results/_train_tune_2024-04-13_11-20-54' in 0.0054s.
# 2024-04-13 11:21:18,587	ERROR tune.py:1044 -- Trials did not complete: [_train_tune_33873_00000, _train_tune_33873_00001, _train_tune_33873_00002, _train_tune_33873_00003, _train_tune_33873_00004]
# 2024-04-13 11:21:18,590	WARNING experiment_analysis.py:568 -- Could not find best trial. Did you pass the correct `metric` parameter?
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 nf.fit(df=Y_df)
#
# File ~/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/neuralforecast/core.py:274, in NeuralForecast.fit(self, df, static_df, val_size, sort_df, use_init_models, verbose)
#     271         print("WARNING: Deleting previously fitted models.")
#     273 for model in self.models:
# --> 274     model.fit(self.dataset, val_size=val_size)
#     276 self._fitted = True
#
# File ~/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/neuralforecast/common/_base_auto.py:373, in BaseAuto.fit(self, dataset, val_size, test_size, random_seed)
#     360 if self.backend == "ray":
#     361     results = self._tune_model(
#     362         cls_model=self.cls_model,
#     363         dataset=dataset,
#    (...)
#     371         config=self.config,
#     372     )
# --> 373     best_config = results.get_best_result().config
#     374 else:
#     375     results = self._optuna_tune_model(
#     376         cls_model=self.cls_model,
#     377         dataset=dataset,
#    (...)
#     383         config=self.config,
#     384     )
#
# File ~/Workspace/github/crypto-quant-lab/.venv/lib/python3.10/site-packages/ray/tune/result_grid.py:160, in ResultGrid.get_best_result(self, metric, mode, scope, filter_nan_and_inf)
#     149     error_msg = (
#     150         "No best trial found for the given metric: "
#     151         f"{metric or self._experiment_analysis.default_metric}. "
#     152         "This means that no trial has reported this metric"
#     153     )
#     154     error_msg += (
#     155         ", or all values reported for this metric are NaN. To not ignore NaN "
#     156         "values, you can set the `filter_nan_and_inf` arg to False."
#     157         if filter_nan_and_inf
#     158         else "."
#     159     )
# --> 160     raise RuntimeError(error_msg)
#     162 return self._trial_to_result(best_trial)
#
# RuntimeError: No best trial found for the given metric: loss. This means that no trial has reported this metric, or all values reported for this metric are NaN. To not ignore NaN values, you can set the `filter_nan_and_inf` arg to False.
